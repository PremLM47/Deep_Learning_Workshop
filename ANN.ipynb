# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
# to drop features
x=df.iloc[:,3:-1] # here we have removed the features  'RowNumber', 'CustomerId', 'Surname' and exited

# %%
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
y=df.iloc[:,-1] # to select only the last column
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
# pd.get_dummies

#Each variable is converted in as many 0/1 variables as there are different values.
# Columns in the output are each named after a value; if the input is a DataFrame,
# he name of the original variable is prepended to the value.

# %%
x['Geography']
# Out:
# 0        France
# 1         Spain
# 2        France
# 3        France
# 4         Spain
#          ...
# 9995     France
# 9996     France
# 9997     France
# 9998    Germany
# 9999     France
# Name: Geography, Length: 10000, dtype: object

# %%
geography=pd.get_dummies(x["Geography"], drop_first=True)
# here out of the three features we have dropped one feature just to reduce the time of training as model can train fast on 2 columns
# if both 0 1 to france and same for others
geography
# Out:
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [10000 rows x 2 columns]

# %%
gender=pd.get_dummies(x["Gender"], drop_first=True) # here we keep only one gender and based on that we can know the value of other
gender
# Out:
#       Male
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 9995     1
# 9996     1
# 9997     0
# 9998     1
# 9999     0
#
# [10000 rows x 1 columns]

# %%
# concate
# to add the new columns to the dataframe
x=pd.concat([x,geography,gender],axis=1)
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
# ...

# %%
x=x.drop(["Geography","Gender"],axis=1) # to drop the columns

# %%
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# ...

# %%
from sklearn.model_selection import train_test_split # importing the train test split model
x_train,x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
x_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 7389          667   34       5       0.00              2          1
# 9275          427   42       1   75681.52              1          1
# 2995          535   29       2  112367.34              1          1
# 5316          654   40       5  105683.63              1          1
# 356           850   57       8  126776.30              2          1
# ...           ...  ...     ...        ...            ...        ...
# 9225          594   32       4  120074.97              2          1
# 4859          794   22       4  114440.24              1          1
# 3264          738   35       5  161274.05              2          1
# 9845          590   38       9       0.00              2          1
# 2732          623   48       1  108076.33              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 7389               0        163830.64        0      1     0
# ...

# %%
y_train
# Out:
# 7389    0
# 9275    0
# 2995    0
# 5316    0
# 356     0
#        ..
# 9225    0
# 4859    0
# 3264    0
# 9845    0
# 2732    1
# Name: Exited, Length: 8000, dtype: int64

# %%
x_test
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9394          597   35       8  131101.04              1          1
# 898           523   40       2  102967.41              1          1
# 2398          706   42       8   95386.82              1          1
# 5906          788   32       4  112079.58              1          0
# 2343          706   38       5  163034.82              2          1
# ...           ...  ...     ...        ...            ...        ...
# 1037          625   24       1       0.00              2          1
# 2899          586   35       7       0.00              2          1
# 9549          578   36       1  157267.95              2          1
# 2740          650   34       4  142393.11              1          1
# 6690          573   30       8  127406.50              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 9394               1        192852.67        1      0     0
# ...

# %%
y_test
# Out:
# 9394    0
# 898     1
# 2398    0
# 5906    0
# 2343    0
#        ..
# 1037    0
# 2899    0
# 9549    0
# 2740    0
# 6690    0
# Name: Exited, Length: 2000, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler # to normalize our data to bring the values in a standard format
sc=StandardScaler()
# converts our data into arrays

# can use lable encoding one hot encoding

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train.shape
# Out:
# (8000, 11)

# %%
x_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR
# Out:
# LogisticRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=LR.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
LR.score(x_train,y_train)*100
# Out:
# 80.85

# %%
LR.score(x_test,y_test)*100
# Out:
# 81.10000000000001

# %% [markdown]
# ANN

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential # it sequentially executes the layers in the network.
from keras.layers import Dense
# Keras Dense layer is the layer that contains all the neurons that are deeply connected within themselves.
# This means that every neuron in the dense layer takes the input from all the other neurons of the previous layer.
# We can add as many dense layers as required. It is one of the most commonly used layers.

# %%
# Initialising the ANN
classifier = Sequential()

# %% [markdown]
# **What is the difference between he and glorot initialization?
# Glorot initialization is recommended for tanh- and sigmoid-based neurons, and he  initialization is recommended for ReLU-based neurons.**

# %%
# Adding the input layer and the first hidden layer

#Initializers define the way to set the initial random weights of Keras layers.
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu',input_dim = 11))

# Adding the second hidden layer
# classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu')) # here we have considered bias as 1 and for those 6x1 = 6

# classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu'))

# Adding the output layer
classifier.add(Dense(units= 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
# Compiling the ANN
#Computes the cross-entropy loss between true labels and predicted labels.
#Use this cross-entropy loss for binary (0 or 1) classification applications.
#Calculates how often predictions equal labels.

classifier.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(x_train, y_train,validation_split=0.33, batch_size = 10,  epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 3s 3ms/step - loss: 0.6136 - accuracy: 0.6785 - val_loss: 0.4889 - val_accuracy: 0.7936
# Epoch 2/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4699 - accuracy: 0.7955 - val_loss: 0.4497 - val_accuracy: 0.7986
# Epoch 3/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4409 - accuracy: 0.8000 - val_loss: 0.4339 - val_accuracy: 0.8061
# Epoch 4/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4265 - accuracy: 0.8091 - val_loss: 0.4260 - val_accuracy: 0.8080
# Epoch 5/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4171 - accuracy: 0.8192 - val_loss: 0.4195 - val_accuracy: 0.8137
# Epoch 6/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4083 - accuracy: 0.8261 - val_loss: 0.4125 - val_accuracy: 0.8167
# Epoch 7/100
# ...

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 6)                 72
#
#  dense_1 (Dense)             (None, 1)                 7
#
# ...
# Total params: 79
# Trainable params: 79
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.811
